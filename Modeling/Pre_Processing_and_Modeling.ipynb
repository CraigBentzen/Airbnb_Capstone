# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path="C:\\Users\\craig\\Documents\\Python Scripts\\Notebooks\\2nd Capstone Project\\RAW_Data"
os.chdir(path)

# %%
df = pd.read_csv('df_for_preprocessing.csv', index_col = 0)

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#      id host_response_time host_is_superhost  host_listings_count  \
# 0  1947     within an hour                 f                    4
# 1  2384     within an hour                 t                    1
# 2  4505       within a day                 t                    1
# 3  7126     within an hour                 t                    2
# 4  9811     within an hour                 f                   10
#
#    host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                          4                    t                      t
# 1                          1                    t                      t
# 2                          1                    t                      t
# 3                          2                    t                      f
# 4                         10                    t                      t
#
#   neighbourhood_cleansed  latitude  longitude property_type        room_type  \
# ...

# %%
to_drop = ['id','host_has_profile_pic', 'host_identity_verified', 'latitude', 'longitude', 'availability_30', 'availability_60', 'availability_90', 'availability_365' ]

# %%
df = df.drop(to_drop, axis=1)

# %%
df.head()
# Out:
#   host_response_time host_is_superhost  host_listings_count  \
# 0     within an hour                 f                    4
# 1     within an hour                 t                    1
# 2       within a day                 t                    1
# 3     within an hour                 t                    2
# 4     within an hour                 f                   10
#
#    host_total_listings_count neighbourhood_cleansed property_type  \
# 0                          4        Near North Side     Apartment
# 1                          1              Hyde Park   Condominium
# 2                          1         South Lawndale     Apartment
# 3                          2              West Town     Apartment
# 4                         10           Lincoln Park     Apartment
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  price  \
# 0  Entire home/apt             2        1.0       0.0   1.0  Real Bed   59.0
# ...

# %%
df = df.replace(['f', 'False'], 0)

# %%
df = df.replace(['t', 'True'], 1)

# %%
#amenities_list isn't included by 10/7
#amenities_list = ['TV', 'Cable_TV', 'Wifi', 'Air_conditioning', 'Kitchen', 'Paid_parking_off_premises', 'Elevator', 'Buzzer/wireless_intercom', 'Heating', 'Washer', 'Dryer', 'Smoke_detector', 'Carbon_monoxide_detector', 'Fire_extinguisher', 'Essentials', 'Hangers', 'Iron', 'Laptop_friendly_workspace', 'translation_missing:_en.hosting_amenity_49', 'translation_missing:_en.hosting_amenity_50', 'Self_check-in', 'Lockbox', 'Hot_water', 'Microwave', 'Refrigerator', 'Dishes_and_silverware', 'Cooking_basics', 'Oven', 'Stove', 'Long_term_stays_allowed', 'Breakfast', 'Free_street_parking', 'First_aid_kit', 'Shampoo', 'Hair_dryer', 'Bed_linens', 'Extra_pillows_and_blankets', 'Coffee_maker', 'Cleaning_before_checkout', 'Host_greets_you', 'Paid_parking_on_premises', 'Shower_gel', 'Trash_can', 'Internet', 'Free_parking_on_premises', 'Pets_live_on_this_property', 'Family/kid_friendly', '24-hour_check-in', 'Private_entrance', 'Bathtub', 'Dishwasher', 'BBQ_grill', 'Patio_or_balcony', 'Garden_or_backyard', 'Luggage_dropoff_allowed', 'Baking_sheet', 'Barbecue_utensils', 'Room-darkening_shades', 'Children’s_dinnerware', 'Game_console', 'Safety_card', 'Lock_on_bedroom_door', 'Children’s_books_and_toys', 'Pack_’n_Play/travel_crib', 'Lake_access', 'Building_staff', 'Wheelchair_accessible', 'Pets_allowed', 'Suitable_for_events', 'Keypad', 'Smart_lock', 'Private_living_room', 'Ethernet_connection', 'Indoor_fireplace', 'Beach_essentials', 'Stair_gates', 'Other', 'Fireplace_guards', 'Wide_entrance_for_guests', 'Flat_path_to_guest_entrance', 'Well-lit_path_to_entrance', 'High_chair', 'Single_level_home', 'Outlet_covers', 'Baby_bath', 'Table_corner_guards', 'Babysitter_recommendations', 'Body_soap', 'Bath_towel', 'Toilet_paper', 'Wide_hallways', 'Bedroom_comforts', 'Bathroom_essentials', 'Hot_tub', 'Washer/Dryer', 'Doorman', 'Gym', 'Smoking_allowed', 'Ceiling_fan', 'DVD_player', 'Jetted_tub', 'Balcony', 'Sound_system', 'Gas_oven', 'Convection_oven', 'Memory_foam_mattress', 'Wine_cooler', 'En_suite_bathroom', 'Walk-in_shower', 'Full_kitchen', 'Pool', 'Other_pet(s)', 'Window_guards', 'Kitchenette', 'Smart_TV', 'Rain_shower', 'Terrace', 'Netflix', 'Soaking_tub', 'EV_charger', 'Hot_water_kettle', 'Stand_alone_steam_shower', 'Breakfast_table', 'Pillow-top_mattress', 'Crib', 'Waterfront', 'Beachfront', 'Pocket_wifi', 'Baby_monitor', 'Changing_table', 'Central_air_conditioning', 'Formal_dining_area', 'Outdoor_seating', 'Ground_floor_access', 'Wide_entrance', 'Extra_space_around_bed', 'Accessible-height_bed', 'Wide_doorway_to_guest_bathroom', 'Accessible-height_toilet', 'Wide_clearance_to_shower', '_toilet', 'Wide_entryway', 'HBO_GO', 'Espresso_machine', 'Standing_valet', 'Heated_floors', 'Hammock', 'Sauna', 'Handheld_shower_head', 'Printer', 'Outdoor_parking', 'Mountain_view', 'Private_bathroom', 'Day_bed', 'Mudroom', 'Projector_and_screen', 'Alfresco_bathtub', 'Firm_mattress', 'Sun_loungers', 'High-resolution_computer_monitor', 'Touchless_faucets', 'Mini_fridge', 'Exercise_equipment', 'Shared_gym', 'Shared_pool', 'Amazon_Echo']

# %%
#df = df.drop(amenities_list, axis=1)

# %%
#amenities_list = ['TV', 'Cable_TV', 'Wifi', 'Air_conditioning', 'Kitchen', 'Paid_parking_off_premises', 'Elevator', 'Buzzer/wireless_intercom', 'Heating', 'Washer', 'Dryer', 'Smoke_detector', 'Carbon_monoxide_detector', 'Fire_extinguisher', 'Essentials', 'Hangers', 'Iron', 'Laptop_friendly_workspace', 'translation_missing:_en.hosting_amenity_49', 'translation_missing:_en.hosting_amenity_50', 'Self_check-in', 'Lockbox', 'Hot_water', 'Microwave', 'Refrigerator', 'Dishes_and_silverware', 'Cooking_basics', 'Oven', 'Stove', 'Long_term_stays_allowed', 'Breakfast', 'Free_street_parking', 'First_aid_kit', 'Shampoo', 'Hair_dryer', 'Bed_linens', 'Extra_pillows_and_blankets', 'Coffee_maker', 'Cleaning_before_checkout', 'Host_greets_you', 'Paid_parking_on_premises', 'Shower_gel', 'Trash_can', 'Internet', 'Free_parking_on_premises', 'Pets_live_on_this_property', 'Family/kid_friendly', '24-hour_check-in', 'Private_entrance', 'Bathtub', 'Dishwasher', 'BBQ_grill', 'Patio_or_balcony', 'Garden_or_backyard', 'Luggage_dropoff_allowed', 'Baking_sheet', 'Barbecue_utensils', 'Room-darkening_shades', 'Children’s_dinnerware', 'Game_console', 'Safety_card', 'Lock_on_bedroom_door', 'Children’s_books_and_toys', 'Pack_’n_Play/travel_crib', 'Lake_access', 'Building_staff', 'Wheelchair_accessible', 'Pets_allowed', 'Suitable_for_events', 'Keypad', 'Smart_lock', 'Private_living_room', 'Ethernet_connection', 'Indoor_fireplace', 'Beach_essentials', 'Stair_gates', 'Other', 'Fireplace_guards', 'Wide_entrance_for_guests',  'Well-lit_path_to_entrance', 'High_chair', 'Single_level_home', 'Outlet_covers', 'Baby_bath',  'Babysitter_recommendations', 'Body_soap', 'Bath_towel', 'Toilet_paper']

# %%
#df = df.drop(amenities_list, axis=1)

# %%
df.head()
# Out:
#   host_response_time  host_is_superhost  host_listings_count  \
# 0     within an hour                  0                    4
# 1     within an hour                  1                    1
# 2       within a day                  1                    1
# 3     within an hour                  1                    2
# 4     within an hour                  0                   10
#
#    host_total_listings_count neighbourhood_cleansed property_type  \
# 0                          4        Near North Side     Apartment
# 1                          1              Hyde Park   Condominium
# 2                          1         South Lawndale     Apartment
# 3                          2              West Town     Apartment
# 4                         10           Lincoln Park     Apartment
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  price  \
# 0  Entire home/apt             2        1.0       0.0   1.0  Real Bed   59.0
# ...

# %%
#columns = ['Bedroom_comforts','Bathroom_essentials','Hot_tub','Doorman','Gym','Smoking_allowed','Gas_oven','Memory_foam_mattress','Walk-in_shower','Full_kitchen','Pool','Smart_TV','Netflix','Hot_water_kettle','Crib','Baby_monitor','Wide_entrance']

# %%
#df = df.drop(columns, axis=1)

# %%
df.head()
# Out:
#   host_response_time  host_is_superhost  host_listings_count  \
# 0     within an hour                  0                    4
# 1     within an hour                  1                    1
# 2       within a day                  1                    1
# 3     within an hour                  1                    2
# 4     within an hour                  0                   10
#
#    host_total_listings_count neighbourhood_cleansed property_type  \
# 0                          4        Near North Side     Apartment
# 1                          1              Hyde Park   Condominium
# 2                          1         South Lawndale     Apartment
# 3                          2              West Town     Apartment
# 4                         10           Lincoln Park     Apartment
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  price  \
# 0  Entire home/apt             2        1.0       0.0   1.0  Real Bed   59.0
# ...

# %%
df_gd = pd.get_dummies(df)

# %%
df_gd.head()
# Out:
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  0                    4                          4
# 1                  1                    1                          1
# 2                  1                    1                          1
# 3                  1                    2                          2
# 4                  0                   10                         10
#
#    accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 0             2        1.0       0.0   1.0   59.0              14
# 1             1        1.0       1.0   1.0   55.0               2
# 2             7        1.0       3.0   5.0  117.0               2
# 3             2        1.0       1.0   1.0   80.0               2
# 4             4        1.0       1.0   0.0  150.0               4
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                  4                      2                  93.0
# ...

# %%
df_gd = df_gd.dropna()

# %%
nas=pd.DataFrame(df_gd.isnull().sum().sort_values(ascending=False)/len(df_gd),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
# Empty DataFrame
# Columns: [percent]
# Index: []

# %%
from sklearn import preprocessing

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import explained_variance_score,mean_absolute_error, accuracy_score
from sklearn.model_selection import train_test_split

# %%
#Linear Regression
# Split the data into a training and test set.
X=df_gd.drop(['price'], axis=1)
y=df_gd.price
#scaler = preprocessing.StandardScaler().fit(X)
#X_scaled=scaler.transform(X) 
#X_train, X_test, y_train, y_test = train_test_split(X_scaled, y ,random_state=5)
X_train, X_test, y_train, y_test = train_test_split(X, y ,random_state=5)

lm = LinearRegression()
model = lm.fit(X_train,y_train)
y_pred = model.predict(X_test)
explained_variance_score(y_test, y_pred)

# initial model accuracy is terrible

#Going to try removing columns that are probably not helpful
# Out:
# -100888551.78205822

# %%
df_gd.head()
# Out:
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  0                    4                          4
# 1                  1                    1                          1
# 2                  1                    1                          1
# 3                  1                    2                          2
# 4                  0                   10                         10
#
#    accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 0             2        1.0       0.0   1.0   59.0              14
# 1             1        1.0       1.0   1.0   55.0               2
# 2             7        1.0       3.0   5.0  117.0               2
# 3             2        1.0       1.0   1.0   80.0               2
# 4             4        1.0       1.0   0.0  150.0               4
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                  4                      2                  93.0
# ...

# %%
to_drop = ['host_is_superhost','host_listings_count','host_total_listings_count','minimum_nights','number_of_reviews_ltm', 'review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','is_business_travel_ready','require_guest_profile_picture','require_guest_phone_verification','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','property_type_Barn','property_type_Bed and breakfast','property_type_Boat','property_type_Boutique hotel','property_type_Bungalow','property_type_Campsite','property_type_Cottage','property_type_Guest suite','property_type_Serviced apartment','property_type_Tiny house','cancellation_policy_flexible','cancellation_policy_moderate','cancellation_policy_strict_14_with_grace_period','cancellation_policy_super_strict_30','cancellation_policy_super_strict_60']

# %%
df_drop = df_gd.drop(to_drop, axis=1)

# %%
X=df_drop.drop(['price'], axis=1)
y=df_drop.price
scaler = preprocessing.StandardScaler().fit(X)
X_scaled=scaler.transform(X) 
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y ,random_state=5)
#X_train, X_test, y_train, y_test = train_test_split(X, y ,random_state=5)

lm = LinearRegression()
model = lm.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(explained_variance_score(y_test, y_pred))
#print(accuracy_score(y_pred, y_test))
# Out:
# -3.290577950093348e+26

# %%
max_iter = 2000

# %%
clf = LogisticRegression()
# Fit the model on the trainng data.
clf.fit(X_train, y_train)
# Print the accuracy from the testing data.
print(accuracy_score(clf.predict(X_test), y_test))
# Out:
# 0.0977258758451137
# C:\Users\craig\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.linear_model import Ridge, RidgeCV
#reg_ridge = Ridge(alpha=.01)
reg_ridge = RidgeCV(alphas=(.01, .1,.5, 1, 10))
reg_ridge.fit(X_train,y_train)
y_pred = model.predict(X_test)
#print(reg.explained_variance_score(y_test, y_pred))

print( reg_ridge.score(X_train,y_train))
print(reg_ridge.score(X_test, y_test))
print(reg_ridge.alpha_)
print(reg_ridge.coef_)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5068679230862305
# 0.46826208574809647
# 10.0
# [ 3.04473344e+01  1.56022484e+01  1.32899852e+01  2.21583165e+00
#   2.67021209e+00  6.13640806e+00  2.76325293e+00 -2.18013666e+01
#   5.59088177e+00 -4.64761117e+00 -3.84229370e+00 -1.84796997e+00
#   8.41723975e+00 -1.12508457e-01  2.05005987e+00  3.05327881e-01
#  -5.22174354e-01 -1.17107346e+00 -2.12753043e+00  2.57136137e+00
#   4.74745629e-01 -1.07388678e+00 -1.01316063e+00 -4.02560704e+00
#  -1.51717858e+00 -3.04312875e+00 -1.92115542e+00 -1.41765730e+00
#  -4.63455365e+00 -1.83858599e+00  2.52435490e-28 -3.93736082e+00
#  -2.73088805e+00 -1.07324779e+00 -1.61934227e+00 -2.24076164e+00
#  -1.40338460e+00 -4.25871511e+00 -7.44794478e-01 -1.86412569e+00
#  -1.21955263e+00 -3.72708504e-02  6.05845175e-28 -6.05034558e-01
#  -1.57794579e+00 -2.04313402e+00 -2.77223991e+00 -5.23931534e-01
#  -2.04725800e+00 -3.08594072e+00 -2.58604949e+00 -2.25222996e+00
#  -2.41781350e+00 -1.39185506e+00  2.48598462e+00  8.88332204e+00
# ...

# %%
from sklearn.linear_model import Lasso, LassoCV
#reg_lasso = Lasso(alpha=.01)
reg_lasso = LassoCV(cv=5, random_state=0)
reg_lasso.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(reg_lasso.score(X_train,y_train))
print(reg_lasso.score(X_test, y_test))
print(reg_lasso.alpha_)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5054104043176014
# 0.46850254313585915
# 0.3730550500342845
# 0.13952059004302397

# %%
from sklearn.linear_model import ElasticNetCV
reg_elastic = ElasticNetCV(cv=5, random_state=0)
reg_elastic.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(reg_elastic.score(X_train,y_train))
print(reg_elastic.score(X_test, y_test))
print(reg_elastic.alpha_)
# Out:
# 0.5050979486509162
# 0.4710292217093389
# 0.13038485894023993

# %%
coef_table = pd.DataFrame(list(X.columns)).copy()
coef_table.insert(len(coef_table.columns),"Lasso_Coefs",reg_lasso.coef_.transpose())
coef_table.insert(len(coef_table.columns),"Ridge_Coefs",reg_ridge.coef_.transpose())
coef_table.insert(len(coef_table.columns),"Elastic_Coefs",reg_elastic.coef_.transpose())

# %%
coef_table.head(200)
# Out:
#                           0  Lasso_Coefs  Ridge_Coefs  Elastic_Coefs
# 0              accommodates    30.749888    30.447334      25.184560
# 1                 bathrooms    15.669019    15.602248      15.164151
# 2                  bedrooms    12.773260    13.289985      13.597315
# 3                      beds     2.047306     2.215832       5.780107
# 4         number_of_reviews     1.550920     2.670212       1.470055
# ..                      ...          ...          ...            ...
# 109         bed_type_Airbed     0.000000    -0.045404       0.000000
# 110          bed_type_Couch     1.211372     1.535021       1.488346
# 111          bed_type_Futon    -0.000000    -0.215687      -0.018194
# 112  bed_type_Pull-out Sofa     0.088836     0.314221       0.371596
# 113       bed_type_Real Bed    -0.205380    -0.492289      -0.244247
#
# [114 rows x 4 columns]

# %%
from sklearn.linear_model import LassoLars
#reg_lasso = Lasso(alpha=.01)
reg_lars = LassoLars(alpha=0.001)
reg_lars.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(reg_lars.score(X_train,y_train))
print(reg_lars.score(X_test, y_test))
#print(reg_lars.alpha_)
# Out:
# 0.5067525145971423
# 0.4686437614099874

# %%
from sklearn.linear_model import BayesianRidge
reg_baysridge = BayesianRidge()
reg_baysridge.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(reg_baysridge.score(X_train,y_train))
print(reg_baysridge.score(X_test, y_test))
# Out:
# 0.5058104290710268
# 0.4704088409136786

# %%
from sklearn.linear_model import LogisticRegressionCV
reg_logit = LogisticRegressionCV(cv=5, random_state=0,max_iter=100, solver='saga')
reg_logit.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(reg_logit.score(X_train,y_train))
print(reg_logit.score(X_test, y_test))
# Out:
# C:\Users\craig\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\craig\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\craig\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-98430288d80e> in <module>
#       1 from sklearn.linear_model import LogisticRegressionCV
# ...

# %%
from sklearn.linear_model import Perceptron
reg_percep = Perceptron(random_state=0)
reg_percep.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(reg_percep.score(X_train,y_train))
print(reg_percep.score(X_test, y_test))
print(accuracy_score(y_test, y_pred))
# Out:
# 0.10878918254456055
# 0.054087277197295634
# 0.13952059004302397

# %%
from sklearn import tree, metrics

# %%
from sklearn.neighbors import KNeighborsClassifier


test_scores = []
train_scores = []

for i in range(1,10):

    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))

# %%
print(train_scores)
print(test_scores)
# Out:
# [1.0, 0.5609506248719525, 0.421839786928908, 0.3525916820323704, 0.3198115140340094, 0.2956361401352182, 0.2765826674861709, 0.2636754763368162, 0.2538414259373079]
# [0.13644744929317762, 0.12845728334357714, 0.11247695144437615, 0.10633066994468347, 0.10325752919483712, 0.10633066994468347, 0.10018438844499078, 0.10141364474492932, 0.10202827289489859]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca.fit_transform(X_train,y_train)
y_pred = model.predict(X_test)
print(pca.score(X_train,y_train))
print(pca.score(X_test, y_test))
# Out:
# -158.50082637152644
# -163.1130290519913

# %%
from sklearn import ensemble

# %%
params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
model = ensemble.GradientBoostingRegressor(**params)

model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error, r2_score
model_score = model.score(X_train,y_train)
# Have a look at R sq to give an idea of the fit ,
# Explained variance score: 1 is perfect prediction
print('R2 sq: ',model_score)
y_pred = model.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Test Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# R2 sq:  0.6905488137348723
# Mean squared error: 4941.81
# Test Variance score: 0.50

# %%
from xgboost import XGBClassifier

# %%
reg_xgb = XGBClassifier()
reg_xgb.fit(X_train, y_train)
y_pred = reg_xgb.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.13952059004302397

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
parameters = {'kernel':['rbf'], 'C':[1, 10, 100]}
svc = svm.SVC()
reg_gs = GridSearchCV(svc, parameters)
reg_gs.fit(X_train, y_train)
y_pred = reg_gs.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# C:\Users\craig\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# 0.13398893669330056

# %%
print(reg_gs.best_params_)
print(reg_gs.best_estimator_)
print(reg_gs.best_score_)
# Out:
# {'C': 100, 'kernel': 'rbf'}
# SVC(C=100)
# 0.13460555900464788
